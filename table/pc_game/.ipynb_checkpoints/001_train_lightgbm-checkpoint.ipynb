# %%
import numpy as np 
import pandas as pd
import os
import sys
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
BASE_DIR = "../../../data/pc_game"

# %%
df_train = pd.read_csv(BASE_DIR + '/train.csv')
df_test = pd.read_csv(BASE_DIR + '/test.csv')
df_sub = pd.read_csv(BASE_DIR + '/sample_submit.csv',header=None)

# %%
df_train
# Out:
#       gameId  blueFirstBlood  blueKills  blueDeaths  blueAssists  \
# 0          0               0          5           8            6
# 1          1               1         10           1            5
# 2          2               0          3          10            2
# 3          3               1          7          10            8
# 4          4               0          4           9            4
# ...      ...             ...        ...         ...          ...
# 7995    9993               1          9           6           14
# 7996    9994               0          3          10            4
# 7997    9995               1          9           3            9
# 7998    9997               0          5          10            6
# 7999    9998               0          6           4            5
#
#       blueEliteMonsters  blueDragons  blueTotalGold  blueTotalExperience  \
# 0                     0            0          14536                17256
# ...

# %%
df_test
# Out:
#       gameId  blueFirstBlood  blueKills  blueDeaths  blueAssists  \
# 0          9               0          7           6            6
# 1         15               0          6           6            6
# 2         18               1          6           4            3
# 3         23               0          5           4            7
# 4         31               0         10           8            9
# ...      ...             ...        ...         ...          ...
# 1995    9971               0          6           3            7
# 1996    9980               0          4           4            4
# 1997    9983               1          6           3            3
# 1998    9996               1         10           9            9
# 1999    9999               0          7          11            8
#
#       blueEliteMonsters  blueDragons  blueTotalGold  blueTotalExperience
# 0                     0            0          16961                18201
# ...

# %%
df_sub
# Out:
#          0  1
# 0        9  0
# 1       15  0
# 2       18  0
# 3       23  0
# 4       31  0
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  0
# 1998  9996  0
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %%
col_li = df_train.columns.tolist()
df_train['blueWins'].value_counts()
# Out:
# 0    4066
# 1    3934
# Name: blueWins, dtype: int64

# %%
df_train.dtypes

# %%
df_train.corr()
# Out:
#                        gameId  blueFirstBlood  blueKills  blueDeaths  \
# gameId               1.000000       -0.001356   0.015867    0.011907
# blueFirstBlood      -0.001356        1.000000   0.283559   -0.325833
# blueKills            0.015867        0.283559   1.000000   -0.079929
# blueDeaths           0.011907       -0.325833  -0.079929    1.000000
# blueAssists          0.013440        0.241781   0.710046   -0.060368
# blueEliteMonsters    0.001194        0.213862   0.246184   -0.223138
# blueDragons          0.001223        0.155051   0.196728   -0.180798
# blueTotalGold        0.012690       -0.111157   0.099387    0.060901
# blueTotalExperience -0.000432        0.033651   0.309264   -0.051879
# blueWins            -0.014944        0.226536   0.337541   -0.237224
#
#                      blueAssists  blueEliteMonsters  blueDragons  \
# gameId                  0.013440           0.001194     0.001223
# blueFirstBlood          0.241781           0.213862     0.155051
# ...

# %%
X = df_train.drop(columns=['gameId','blueTotalGold','blueWins'])
y = df_train['blueWins']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
parameters = {'max_depth':[2,3], 'n_estimators':[500,1000,2000]}
clf = RandomForestClassifier(max_depth=2, random_state=42)
cv = GridSearchCV(clf, parameters)
cv.fit(X_train, y_train)
clf = cv.best_estimator_
clf.score(X_test,y_test)

# %%
clf.score(X_train,y_train)

# %%
cv.best_params_
# Out:
# {'max_depth': 3, 'n_estimators': 1000}

# %%
clf.feature_importances_
# Out:
# array([0.03515566, 0.15226024, 0.05219554, 0.09608874, 0.10124159,
#        0.04057057, 0.52248766])

# %%
pre = clf.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-da6718ab8840> in <module>
# ----> 1 pre = clf.predict(df_test)
#
# ~\miniconda3\envs\env_pytorch\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# ~\miniconda3\envs\env_pytorch\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# ~\miniconda3\envs\env_pytorch\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# ...

# %%
df_sub[1] = pre

# %%
df_sub.to_csv(BASE_DIR+'/subbmission.csv',header=None)

# %%
import IPython
print(IPython.sys_info())
# Out:
# {'commit_hash': '223e783c4',
#  'commit_source': 'installation',
#  'default_encoding': 'cp932',
#  'ipython_path': 'C:\\Users\\tsuchiya\\miniconda3\\envs\\env_pytorch\\Lib\\site-packages\\IPython',
#  'ipython_version': '7.19.0',
#  'os_name': 'nt',
#  'platform': 'Windows-10-10.0.19041-SP0',
#  'sys_executable': 'C:\\Users\\tsuchiya\\miniconda3\\envs\\env_pytorch\\python.exe',
#  'sys_platform': 'win32',
#  'sys_version': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit '
#                 '(AMD64)]'}

# %%
df_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f45937856810> in <module>
# ----> 1 df_train
#
# NameError: name 'df_train' is not defined
